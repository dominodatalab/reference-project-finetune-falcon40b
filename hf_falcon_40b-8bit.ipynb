# %%
! pip install ipywidgets
! pip install protobuf==3.20.*
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: ipywidgets in /home/domino/.local/lib/python3.10/site-packages (8.0.7)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (5.9.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (6.23.3)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /home/domino/.local/lib/python3.10/site-packages (from ipywidgets) (3.0.8)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (8.14.0)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /home/domino/.local/lib/python3.10/site-packages (from ipywidgets) (4.0.8)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: comm>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets) (23.1)
# Requirement already satisfied: pyzmq>=20 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets) (25.1.0)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets) (5.3.1)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.7)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.4)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets) (8.3.0)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.3.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (3.0.38)
# Requirement already satisfied: stack-data in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (0.18.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets) (3.8.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# WARNING: You are using pip version 21.2.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/usr/bin/python -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: protobuf==3.20.* in /home/domino/.local/lib/python3.10/site-packages (3.20.3)
# WARNING: You are using pip version 21.2.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/usr/bin/python -m pip install --upgrade pip' command.

# %%
import os
import nvidia
import time

cuda_install_dir = '/'.join(nvidia.__file__.split('/')[:-1]) + '/cuda_runtime/lib/'
os.environ['LD_LIBRARY_PATH'] =  cuda_install_dir

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

model_id = "tiiuae/falcon-40b"
bnb_config = BitsAndBytesConfig(load_in_8bit=True)


tokenizer = AutoTokenizer.from_pretrained(model_id)

# Falcon requires you to allow remote code execution. This is because the model uses a new architecture that is not part of transformers yet.
# The code is provided by the model authors in the repo.

model = AutoModelForCausalLM.from_pretrained(model_id, trust_remote_code=True, quantization_config=bnb_config, device_map="auto", cache_dir='/mnt')
# Out:
# [2023-07-25 03:08:04,304] [INFO] [real_accelerator.py:133:get_accelerator] Setting ds_accelerator to cuda (auto detect)
#
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please run
#
# python -m bitsandbytes
#
#  and submit this information together with your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# ================================================================================
# bin /usr/local/lib/python3.10/dist-packages/bitsandbytes/libbitsandbytes_cuda121.so
# CUDA_SETUP: WARNING! libcudart.so not found in any environmental path. Searching in backup paths...
# CUDA SETUP: CUDA runtime path found: /usr/local/cuda/lib64/libcudart.so
# CUDA SETUP: Highest compute capability among GPUs detected: 8.6
# CUDA SETUP: Detected CUDA version 121
# CUDA SETUP: Loading binary /usr/local/lib/python3.10/dist-packages/bitsandbytes/libbitsandbytes_cuda121.so...
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/usr/local/lib/python3.10/dist-packages/nvidia/cuda_runtime/lib')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: /usr/local/lib/python3.10/dist-packages/nvidia/cuda_runtime/lib/ did not contain ['libcudart.so', 'libcudart.so.11.0', 'libcudart.so.12.0'] as expected! Searching further paths...
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('tcp'), PosixPath('80'), PosixPath('//172.20.213.158')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.104.217'), PosixPath('tcp'), PosixPath('80')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.111.51'), PosixPath('tcp'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.136.114'), PosixPath('tcp'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('tcp'), PosixPath('//172.20.59.218'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.13.75'), PosixPath('9500'), PosixPath('tcp')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('9000'), PosixPath('tcp'), PosixPath('//172.20.158.81')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('tcp'), PosixPath('//172.20.57.184'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('tcp'), PosixPath('//172.20.131.145'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('tcp'), PosixPath('8080'), PosixPath('//172.20.15.4')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('tcp'), PosixPath('80'), PosixPath('//172.20.231.94')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.16.217'), PosixPath('tcp'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.79.80'), PosixPath('tcp'), PosixPath('80')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('9000'), PosixPath('tcp'), PosixPath('//172.20.180.98')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.156.36'), PosixPath('tcp'), PosixPath('80')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('tcp'), PosixPath('//172.20.160.37'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('9000'), PosixPath('tcp'), PosixPath('//172.20.231.94')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('9000'), PosixPath('//172.20.29.34'), PosixPath('tcp')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('tcp'), PosixPath('//172.20.240.144'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.132.127'), PosixPath('tcp'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.246.135'), PosixPath('tcp'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.133.176'), PosixPath('tcp'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.72.167'), PosixPath('tcp'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('9000'), PosixPath('//172.20.118.142'), PosixPath('tcp')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('tcp'), PosixPath('//172.20.177.159'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('${CURL} --silent --show-error -X POST http'), PosixPath('//localhost'), PosixPath('9000/executor/endSingleRun/64bf212082ef215e98abcd6b?exitCode=$code_at_exit')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.235.187'), PosixPath('tcp'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.47.222'), PosixPath('tcp'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('tcp'), PosixPath('80'), PosixPath('//172.20.129.6')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('tcp'), PosixPath('//172.20.121.151'), PosixPath('80')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('tcp'), PosixPath('80'), PosixPath('//172.20.6.10')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('tcp'), PosixPath('80'), PosixPath('//172.20.21.29')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.171.210'), PosixPath('tcp'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('tcp'), PosixPath('80'), PosixPath('//172.20.180.98')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('9000'), PosixPath('//172.20.13.75'), PosixPath('tcp')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.118.142'), PosixPath('tcp'), PosixPath('80')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('tcp'), PosixPath('//172.20.194.39'), PosixPath('80')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('9000'), PosixPath('tcp'), PosixPath('//172.20.210.80')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('tcp'), PosixPath('80'), PosixPath('//172.20.158.81')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.10.236'), PosixPath('tcp'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.79.80'), PosixPath('9000'), PosixPath('tcp')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('tcp'), PosixPath('80'), PosixPath('//172.20.210.80')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('tcp'), PosixPath('80'), PosixPath('//172.20.126.100')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('9000'), PosixPath('//172.20.156.36'), PosixPath('tcp')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('tcp'), PosixPath('//172.20.214.186'), PosixPath('8000')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('tcp'), PosixPath('80'), PosixPath('//172.20.25.167')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('9000'), PosixPath('tcp'), PosixPath('//172.20.21.29')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('tcp'), PosixPath('80'), PosixPath('//172.20.226.167')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('tcp'), PosixPath('//172.20.29.34'), PosixPath('80')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.55.241'), PosixPath('tcp'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.23.56'), PosixPath('tcp'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('grpc'), PosixPath('8080'), PosixPath('//datasource-proxy.domino-platform')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//localhost'), PosixPath('80'), PosixPath('http')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('tcp'), PosixPath('8080'), PosixPath('//172.20.94.14')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('443'), PosixPath('tcp'), PosixPath('//172.20.0.1')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.8.157'), PosixPath('9000'), PosixPath('tcp')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('9000'), PosixPath('tcp'), PosixPath('//172.20.126.100')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.243.128'), PosixPath('tcp'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.103.232'), PosixPath('443'), PosixPath('tcp')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('9000'), PosixPath('tcp'), PosixPath('//172.20.25.167')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('9000'), PosixPath('tcp'), PosixPath('//172.20.125.61')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('9000'), PosixPath('//172.20.121.151'), PosixPath('tcp')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.86.142'), PosixPath('tcp'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.141.223'), PosixPath('tcp'), PosixPath('80')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.142.51'), PosixPath('tcp'), PosixPath('80')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('tcp'), PosixPath('8080'), PosixPath('//172.20.115.50')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('tcp'), PosixPath('80'), PosixPath('//172.20.125.61')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.8.157'), PosixPath('tcp'), PosixPath('80')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.39.245'), PosixPath('tcp'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.22.231'), PosixPath('tcp'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.7.88'), PosixPath('tcp'), PosixPath('80')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.7.88'), PosixPath('9000'), PosixPath('tcp')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.206.15'), PosixPath('tcp'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.129.171'), PosixPath('tcp'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('9000'), PosixPath('tcp'), PosixPath('//172.20.129.6')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.218.71'), PosixPath('tcp'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.64.231'), PosixPath('443'), PosixPath('tcp')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('9000'), PosixPath('tcp'), PosixPath('//172.20.226.167')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('tcp'), PosixPath('//172.20.216.70'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.86.191'), PosixPath('tcp'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//nucleus-frontend.domino-platform'), PosixPath('80'), PosixPath('http')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('9000'), PosixPath('tcp'), PosixPath('//172.20.6.10')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('9000'), PosixPath('//172.20.194.39'), PosixPath('tcp')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.141.223'), PosixPath('9000'), PosixPath('tcp')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('tcp'), PosixPath('//172.20.109.209'), PosixPath('80')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('tcp'), PosixPath('//172.20.244.60'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.133.162'), PosixPath('tcp'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.163.168'), PosixPath('tcp'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('tcp'), PosixPath('80'), PosixPath('//172.20.24.238')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('9000'), PosixPath('//172.20.142.51'), PosixPath('tcp')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/repos')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.20.104.217'), PosixPath('9000'), PosixPath('tcp')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('9000'), PosixPath('//172.20.109.209'), PosixPath('tcp')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('tcp'), PosixPath('//172.20.133.152'), PosixPath('8080')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('5001'), PosixPath('tcp'), PosixPath('//172.20.214.186')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('80'), PosixPath('http'), PosixPath('//datasource-proxy.domino-platform')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('9000'), PosixPath('tcp'), PosixPath('//172.20.213.158')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//localhost'), PosixPath('8899'), PosixPath('http')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('9000'), PosixPath('tcp'), PosixPath('//172.20.24.238')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('module'), PosixPath('//matplotlib_inline.backend_inline')}
#   warn(msg)
# Loading checkpoint shards:   0%|          | 0/9 [00:00<?, ?it/s]

# %%
# Set the Falcon tokenizer
tokenizer.pad_token = tokenizer.eos_token

# %%
from peft import prepare_model_for_kbit_training

model.gradient_checkpointing_enable()
model = prepare_model_for_kbit_training(model)

# %%
def print_trainable_parameters(model):
    """
    Prints the number of trainable parameters in the model.
    """
    trainable_params = 0
    all_param = 0
    for _, param in model.named_parameters():
        all_param += param.numel()
        if param.requires_grad:
            trainable_params += param.numel()
    print(
        f"trainable params: {trainable_params} || all params: {all_param} || trainable%: {100 * trainable_params / all_param}"
    )

# %%
from peft import LoraConfig, get_peft_model

config = LoraConfig(
    r=8,
    lora_alpha=32,
    target_modules=[
        "query_key_value",
        "dense",
        "dense_h_to_4h",
        "dense_4h_to_h",
        ],
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM"
)

model = get_peft_model(model, config)
print_trainable_parameters(model)
# Out:
# trainable params: 55541760 || all params: 41358835712 || trainable%: 0.13429236835089367

# %%
from datasets import load_dataset

# Load dataset from the hub
dataset = load_dataset("samsum")

print(f"Train dataset size: {len(dataset['train'])}")
print(f"Test dataset size: {len(dataset['test'])}")
# Out:
# Found cached dataset samsum (/home/domino/.cache/huggingface/datasets/samsum/samsum/0.0.0/f1d7c6b7353e6de335d444e424dc002ef70d1277109031327bc9cc6af5d3d46e)
#   0%|          | 0/3 [00:00<?, ?it/s]
# Train dataset size: 14732
# Test dataset size: 819

# %%
from random import randint

# custom instruct prompt start
prompt_template = f"Summarize the chat dialogue:\n{{dialogue}}\n---\nSummary:\n{{summary}}{{eos_token}}"

# template dataset to add prompt to each sample
def template_dataset(sample):
    sample["text"] = prompt_template.format(dialogue=sample["dialogue"],
                                            summary=sample["summary"],
                                            eos_token=tokenizer.eos_token)
    return sample


# apply prompt template per sample
train_dataset = dataset["train"].map(template_dataset, remove_columns=list(dataset["train"].features))
train_dataset = train_dataset.select(range(500))
print(train_dataset[randint(0, len(train_dataset))]["text"])
# Out:
# Loading cached processed dataset at /home/domino/.cache/huggingface/datasets/samsum/samsum/0.0.0/f1d7c6b7353e6de335d444e424dc002ef70d1277109031327bc9cc6af5d3d46e/cache-3f12bbe31675d8d9.arrow
# Summarize the chat dialogue:
# Elle: I'm quiting
# Emma: what? why?
# Emma: what happened??
# Elle: the atmosphere in the office is unbearable!
# Emma: your boss again?
# Elle: yeah
# Emma: don't you have like a person you can report on these incidents to?
# Elle: we do but they are just as afraid of him as we are
# Emma: dammit that's not right
# Elle: :(
# Emma: Well then start sending out some CVs
# Elle: you think?
# Emma: You'll find job in a minute!!
# ---
# Summary:
# Elle quit her job because of some incidents with her boss. She is going to look for a new job.<|endoftext|>

# %%
# apply prompt template per sample
test_dataset = dataset["test"].map(template_dataset, remove_columns=list(dataset["test"].features))
test_dataset = test_dataset.select(range(100))
# Out:
# Loading cached processed dataset at /home/domino/.cache/huggingface/datasets/samsum/samsum/0.0.0/f1d7c6b7353e6de335d444e424dc002ef70d1277109031327bc9cc6af5d3d46e/cache-7b2e1367f7be0c6a.arrow

# %%
# tokenize and chunk dataset
lm_train_dataset = train_dataset.map(
    lambda sample: tokenizer(sample["text"]), batched=True, batch_size=24, remove_columns=list(train_dataset.features)
)


lm_test_dataset = test_dataset.map(
    lambda sample: tokenizer(sample["text"]), batched=True, remove_columns=list(test_dataset.features)
)

# Print total number of samples
print(f"Total number of train samples: {len(lm_train_dataset)}")
print(f"Total number of test samples: {len(lm_test_dataset)}")
# Out:
# Loading cached processed dataset at /home/domino/.cache/huggingface/datasets/samsum/samsum/0.0.0/f1d7c6b7353e6de335d444e424dc002ef70d1277109031327bc9cc6af5d3d46e/cache-e93fd0bb364b55b3.arrow
# Loading cached processed dataset at /home/domino/.cache/huggingface/datasets/samsum/samsum/0.0.0/f1d7c6b7353e6de335d444e424dc002ef70d1277109031327bc9cc6af5d3d46e/cache-1d40a078fea40e09.arrow
# Total number of train samples: 500
# Total number of test samples: 100

# %%
import transformers

# We set num_train_epochs=1 simply to run a demonstration

trainer = transformers.Trainer(
    model=model,
    train_dataset=lm_train_dataset,
    eval_dataset=lm_test_dataset,
    args=transformers.TrainingArguments(
        per_device_train_batch_size=4,
        per_device_eval_batch_size=4,
        logging_dir='/mnt/hf_logs_sample_8bit',
        logging_steps=2,
        num_train_epochs=1,
        learning_rate=2e-4,
        bf16=True,
        save_strategy = "epoch",
        output_dir="/mnt/outputs_sample_8bit",
    ),
    data_collator=transformers.DataCollatorForLanguageModeling(tokenizer, mlm=False),
)
model.config.use_cache = False  # silence the warnings. Please re-enable for inference!

# %%
# Start training
trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# You're using a PreTrainedTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/autograd/_functions.py:321: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/autograd/_functions.py:321: UserWarning: MatMul8bitLt: inputs will be cast from torch.bfloat16 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#     <div>
#
#       <progress value='125' max='125' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [125/125 21:37, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2</td>
#       <td>1.993700</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.057100</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.827300</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.848300</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.639600</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.857600</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.868700</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.780600</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.627000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.797400</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.812800</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.656300</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.868400</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.814900</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.664600</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>1.703000</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>1.629000</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>1.707800</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>1.631500</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.716000</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>1.641500</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>1.778100</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>1.792300</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>1.444600</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.628000</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>1.783500</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>1.591100</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>1.601300</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>1.420600</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.773100</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>1.653100</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>1.689200</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>1.792400</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>2.072900</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.605100</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>1.919500</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>1.894800</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>1.566400</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>1.735200</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.530500</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>1.548200</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>1.755600</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>1.682400</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>1.733500</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>1.653700</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>1.553500</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>1.766200</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>1.716100</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>1.604300</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.377400</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>1.675700</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>1.654400</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>1.667100</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>1.692700</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>1.714900</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>1.612300</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>1.843700</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>1.960800</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>1.664000</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>1.652000</td>
#     </tr>
#     <tr>
#       <td>122</td>
#       <td>1.612700</td>
#     </tr>
#     <tr>
#       <td>124</td>
#       <td>1.593900</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=125, training_loss=1.7131476764678955, metrics={'train_runtime': 1344.7226, 'train_samples_per_second': 0.372, 'train_steps_per_second': 0.093, 'total_flos': 3.987605272933171e+16, 'train_loss': 1.7131476764678955, 'epoch': 1.0})

# %%
#evaluate and return the metrics
trainer.evaluate()
# Out:
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/autograd/_functions.py:321: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/autograd/_functions.py:321: UserWarning: MatMul8bitLt: inputs will be cast from torch.bfloat16 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#     <div>
#
#       <progress value='25' max='25' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [25/25 00:53]
#     </div>
# {'eval_loss': 1.6955502033233643,
#  'eval_runtime': 54.9718,
#  'eval_samples_per_second': 1.819,
#  'eval_steps_per_second': 0.455,
#  'epoch': 1.0}

# %%
# Load dataset from the hub
test_dataset = load_dataset("samsum", split="test")

# select a random test sample
sample = test_dataset[randint(0, len(test_dataset))]

# format sample
prompt_template = f"Summarize the chat dialogue:\n{{dialogue}}\n---\nSummary:\n"

test_sample = prompt_template.format(dialogue=sample["dialogue"])

print(test_sample)
# Out:
# Found cached dataset samsum (/home/domino/.cache/huggingface/datasets/samsum/samsum/0.0.0/f1d7c6b7353e6de335d444e424dc002ef70d1277109031327bc9cc6af5d3d46e)
# Summarize the chat dialogue:
# Richie: Pogba
# Clay: Pogboom
# Richie: what a s strike yoh!
# Clay: was off the seat the moment he chopped the ball back to his right foot
# Richie: me too dude
# Clay: hope his form lasts
# Richie: This season he's more mature
# Clay: Yeah, Jose has his trust in him
# Richie: everyone does
# Clay: yeah, he really deserved to score after his first 60 minutes
# Richie: reward
# Clay: yeah man
# Richie: cool then
# Clay: cool
# ---
# Summary:

# %%
input_ids = tokenizer(test_sample, return_tensors="pt").input_ids

# %%
#set the tokens for the summary evaluation
tokens_for_summary = 30
output_tokens = input_ids.shape[1] + tokens_for_summary

start_time = time.time()

with torch.no_grad():
    outputs = model.generate(inputs=input_ids, do_sample=True, max_length=output_tokens)

end_time = time.time()
gen_text = tokenizer.batch_decode(outputs)[0]
print(gen_text)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1261: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation )
#   warnings.warn(
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1454: UserWarning: You are calling .generate() with the `input_ids` being on a device type different than your model's device. `input_ids` is on cpu, whereas the model is on cuda. You may experience unexpected behaviors or slower generation. Please make sure that you have put `input_ids` to the correct device by calling for example input_ids = input_ids.to('cuda') before running `.generate()`.
#   warnings.warn(
# Summarize the chat dialogue:
# Richie: Pogba
# Clay: Pogboom
# Richie: what a s strike yoh!
# Clay: was off the seat the moment he chopped the ball back to his right foot
# Richie: me too dude
# Clay: hope his form lasts
# Richie: This season he's more mature
# Clay: Yeah, Jose has his trust in him
# Richie: everyone does
# Clay: yeah, he really deserved to score after his first 60 minutes
# Richie: reward
# Clay: yeah man
# Richie: cool then
# Clay: cool
# ---
# Summary:
# Richie and Clay are talking about Pogba's strike. He really deserves a score after his play. Pogba played well, so

# %%
print(f'\nTook {round(end_time - start_time, 3)} s')
# Out:
# Took 14.582 s
